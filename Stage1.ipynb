# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %% [markdown]
# ### Data import and define variables

# %%
df = pd.read_csv("M3_CancerMod.csv")

# List of biomarker and bacteria columns
biomarkers = ['miRNA10', 'miRNA12', 'miRNA15', 'miRNA24', 'miRNA36', 'GDf13', 'GDf9', 'GDf6', 'GDf5']
bacteria = ['Helicobacter', 'Coriobacteriaceae', 'Bacteroidales', 'Campylobacter', 
            'Lactobacillus', 'Blautia', 'S247', 'Odoribacter', 'Mucispirillum', 
            'Campylobacterales', 'Bromii', 'Clostridiales', 'Christensenellaceae', 
            'Helicobacteraceae', 'Bizzozeronii', 'H.Pylori', 'Ruminococcaceae', 
            'Oscillospira', 'Ruminococcus', 'Mogibacteriaceae', 'Sutterella', 'Anaeroplasma']

print(df)
# Out:
#     Sample Condition  Set   Gender        Age  miRNA10  miRNA12  miRNA15  \
# 0      1.0    Stage3    A        F  48.000000    32.38    8.643    1.023
# 1      2.0    Stage2    A        M  49.000000    37.40      NaN    0.921
# 2      3.0    Stage3    A        M  40.000000    52.16    8.682    0.490
# 3      4.0    Stage2    A        F  54.000000    25.18    4.307    0.560
# 4      5.0    Stage2    A        M  36.000000    34.67    8.439    1.140
# 5      6.0    Stage1    A        M  24.000000    39.27    5.255    0.698
# 6      7.0    Stage4    A        M  57.000000    37.82    6.475    0.572
# 7      8.0    Stage2    A        F  54.000000    37.44    7.766    1.033
# 8      9.0    Stage4    A        F  56.000000    41.71    9.825    0.683
# 9     10.0    Stage4    A        M  66.000000    51.11    9.863    1.094
# 10    11.0    Stage4    A        F  47.000000    35.25    7.181    0.772
# 11    12.0    Stage1    A        M  35.000000    22.73    3.856    0.659
# ...
